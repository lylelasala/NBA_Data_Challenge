# %% [markdown]
# # Nba Regular Season 2018-19 Data Challenge
#
# Your task will be to take the dataset given, and create an analysis answering the following 10 questions. This project will again test your knowledge of pandas in order to find the answers needed given the data you are presented with.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
# nbastats = pd.read_csv('/Users/lylelasala/Documents/work/Data Sci/Python/nbastats2018_2019.csv', sep = ',')
# nbastats

import pandas as pd

# Set options to display all columns and rows
pd.set_option('display.max_columns', None)  # Display all columns
pd.set_option('display.expand_frame_repr', False)  # Prevent wrapping of columns
pd.set_option('display.max_rows', None)  # Display all rows

# Read the CSV file
nbastats = pd.read_csv('/Users/lylelasala/Documents/work/Data Sci/Python/nbastats2018_2019.csv', sep=',')

# Display the DataFrame
nbastats
# Out:
#                          Name  Height  Weight                    Team  Age    Salary  Points  Blocks  Steals  Assists  Rebounds    FT%   FTA   FG3%  FG3A    FG%   FGA    MP   G   PER   OWS  DWS    WS   WS48   USG   BPM  VORP
# 0                Alex Abrines      78     200   Oklahoma City Thunder   25   5455236     5.3     0.2     0.5      0.6       1.5  0.923   0.4  0.323   4.1  0.357   5.1  19.0  31   6.3   0.1  0.6   0.6  0.053  12.2  -3.4  -0.2
# 1                  Quincy Acy      79     240            Phoenix Suns   28    213949     1.7     0.4     0.1      0.8       2.5  0.700   1.0  0.133   1.5  0.222   1.8  12.3  10   2.9  -0.1  0.0  -0.1 -0.022   9.2  -5.9  -0.1
# 2                Jaylen Adams      74     190           Atlanta Hawks   22    236854     3.2     0.1     0.4      1.9       1.8  0.778   0.3  0.338   2.2  0.345   3.2  12.6  34   7.6  -0.1  0.2   0.1  0.011  13.5  -4.4  -0.3
# ...

# %%
# Print the column names of the DataFrame
print(nbastats.columns)
# Out:
# Index(['Name', 'Height', 'Weight', 'Team', 'Age', 'Salary', 'Points', 'Blocks',
#        'Steals', 'Assists', 'Rebounds', 'FT%', 'FTA', 'FG3%', 'FG3A', 'FG%',
#        'FGA', 'MP', 'G', 'PER', 'OWS', 'DWS', 'WS', 'WS48', 'USG', 'BPM',
#        'VORP'],
#       dtype='object')

# %% [markdown]
# # What was the average age of player in the league?

# %%
average_age = nbastats['Age'].mean()

print(f"The average age of players in the league is {average_age:.2f} years.")
# Out:
# The average age of players in the league is 25.90 years.

# %% [markdown]
# # What player scored the most points?

# %%
max_points = nbastats['Points'].max()

players_with_max_points = nbastats[nbastats['Points'] == max_points]['Name']

for player in players_with_max_points:
    print(f"The player who scored the most points is {player} with {max_points} points.")
# Out:
# The player who scored the most points is James Harden with 36.1 points.

# %% [markdown]
# # What player had the most blocks during the season? Was it a post player (F/C)?

# %%
most_blocks = nbastats['Blocks'].max()
most_blocks_player = nbastats[nbastats['Blocks'] == most_blocks]['Name'].values[0]

most_blocks_player_position = nbastats[nbastats['Name'] == most_blocks_player]['Name'].values[0]
is_post_player = most_blocks_player_position in post_positions

print(f"{most_blocks_player} had the most blocks ({most_blocks}) and {'is' if is_post_player else 'is not'} a post player.")
# Out:
# Myles Turner had the most blocks (2.7) and is not a post player.

# %% [markdown]
# # Based on the regular season, who had the best chance to win a title given their win percentage?

# %%
most_wins_team = nbastats[nbastats['WS'] == nbastats['WS'].max()]['Team'].values[0]

print(f"The team with the most wins is {most_wins_team}.")
# Out:
# The team with the most wins is Houston Rockets.

# %% [markdown]
# # What player had the best 3-pt percentage?

# %%
three_point_pct = nbastats['FG3%'] / nbastats['FG3A']

best_three_point_player = nbastats[three_point_pct == three_point_pct.max()]['Name'].values[0]

print(f"The player with the best 3-point shooting percentage is {best_three_point_player}.")
# Out:
# The player with the best  3-point shooting percentage is Willie Cauley-Stein.

# %% [markdown]
# # Who played the most minutes during the season

# %%
most_minutes_player = nbastats[nbastats['MP'] == nbastats['MP'].max()]['Name'].values[0]

print(f"The player who played the most minutes during the season is {most_minutes_player}.")
# Out:
# The player who played the most minutes during the season is Bradley Beal.

# %% [markdown]
# # What player given their player effiecency rating was the clutchest during the season?

# %%
clutchest_player = nbastats[nbastats['PER'] == nbastats['PER'].max()]['Name'].values[0]

print(f"The player with the highest PER, considered potentially the clutchest, is {clutchest_player}.")
# Out:
# The player with the highest PER, considered potentially the clutchest, is Zhou Qi.

# %% [markdown]
# # What team had the youngest roster?

# %%
print(nbastats[['Team', 'Age']].groupby('Team').mean())

print("The Chicago Bulls had the youngest roster this season")
# Out:
#                               Age
# Team
# Atlanta Hawks           26.476190
# Boston Celtics          25.600000
# Brooklyn Nets           25.555556
# Charlotte Hornets       26.000000
# Chicago Bulls           24.312500
# Cleveland Cavaliers     26.000000
# Dallas Mavericks        27.866667
# Denver Nuggets          25.266667
# Detroit Pistons         26.266667
# Golden State Warriors   27.866667
# Houston Rockets         27.923077
# Indiana Pacers          25.058824
# Los Angeles Clippers    27.105263
# Los Angeles Lakers      26.625000
# Memphis Grizzlies       25.647059
# Miami Heat              28.181818
# Milwaukee Bucks         26.928571
# Minnesota Timberwolves  26.625000
# New Orleans Pelicans    25.777778
# New York Knicks         24.625000
# Oklahoma City Thunder   25.750000
# Orlando Magic           24.533333
# Philadelphia 76ers      26.352941
# Phoenix Suns            24.761905
# Portland Trail Blazers  24.857143
# Sacramento Kings        24.400000
# ...

# %% [markdown]
# # Who is the highest paid player during the seasion?

# %%
highest_paid_player = nbastats[nbastats['Salary'] == nbastats['Salary'].max()]['Name'].values[0]

print(f"The highest paid player during the season is {highest_paid_player}.")
# Out:
# The highest paid player during the season is John Jenkins.

# %% [markdown]
# # At the end of a game, who WOULDN'T you want on the Free Throw Line?

# %%
nbastats['FT%'] = nbastats['FT%'] / nbastats['FTA']

worst_ft_player = nbastats[nbastats['FT%'] == nbastats['FT%'].min()]['Name'].values[0]

print(f"The player with the worst free throw percentage is {worst_ft_player}.")
# Out:
# The player with the worst free throw percentage is Haywood Highsmith.
